# %% [markdown]
# <a href="https://colab.research.google.com/github/DuplamenteH/Ds/blob/master/jokes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



# %matplotlib inline
sns.set_style('darkgrid')

# %%
data = pd.read_csv('high_diamond_ranked_10min.csv')
data.head()
# Out:
#        gameId  blueWins  ...  redCSPerMin  redGoldPerMin
# 0  4519157822         0  ...         19.7         1656.7
# 1  4523371949         0  ...         24.0         1762.0
# 2  4521474530         0  ...         20.3         1728.5
# 3  4524384067         0  ...         23.5         1647.8
# 4  4436033771         0  ...         22.5         1740.4
#
# [5 rows x 40 columns]

# %%
data.describe
# Out:
# <bound method NDFrame.describe of           gameId  blueWins  ...  redCSPerMin  redGoldPerMin
# 0     4519157822         0  ...         19.7         1656.7
# 1     4523371949         0  ...         24.0         1762.0
# 2     4521474530         0  ...         20.3         1728.5
# 3     4524384067         0  ...         23.5         1647.8
# 4     4436033771         0  ...         22.5         1740.4
# ...          ...       ...  ...          ...            ...
# 9874  4527873286         1  ...         22.9         1524.6
# 9875  4527797466         1  ...         20.6         1545.6
# 9876  4527713716         0  ...         26.1         1831.9
# 9877  4527628313         0  ...         24.7         1529.8
# 9878  4523772935         1  ...         20.1         1533.9
#
# [9879 rows x 40 columns]>

# %%
data.describe()
# Out:
#              gameId     blueWins  ...  redCSPerMin  redGoldPerMin
# count  9.879000e+03  9879.000000  ...  9879.000000    9879.000000
# mean   4.500084e+09     0.499038  ...    21.734923    1648.904140
# std    2.757328e+07     0.500024  ...     2.191167     149.088841
# min    4.295358e+09     0.000000  ...    10.700000    1121.200000
# 25%    4.483301e+09     0.000000  ...    20.300000    1542.750000
# 50%    4.510920e+09     0.000000  ...    21.800000    1637.800000
# 75%    4.521733e+09     1.000000  ...    23.300000    1741.850000
# max    4.527991e+09     1.000000  ...    28.900000    2273.200000
#
# [8 rows x 40 columns]

# %%
data.shape
# Out:
# (9879, 40)

# %%
data.corr().round(4)
# Out:
#                               gameId  blueWins  ...  redCSPerMin  redGoldPerMin
# gameId                        1.0000    0.0010  ...      -0.0051        -0.0106
# blueWins                      0.0010    1.0000  ...      -0.2122        -0.4114
# blueWardsPlaced               0.0054    0.0001  ...      -0.0124        -0.0057
# blueWardsDestroyed           -0.0121    0.0442  ...       0.0400        -0.0675
# blueFirstBlood               -0.0116    0.2018  ...      -0.1567        -0.3015
# blueKills                    -0.0390    0.3374  ...      -0.4722        -0.1611
# blueDeaths                   -0.0132   -0.3393  ...      -0.0405         0.8857
# blueAssists                  -0.0233    0.2767  ...      -0.3375        -0.1339
# blueEliteMonsters             0.0166    0.2219  ...      -0.0748        -0.2166
# blueDragons                   0.0090    0.2138  ...      -0.0598        -0.1929
# blueHeralds                   0.0156    0.0924  ...      -0.0463        -0.1096
# ...

# %%
cols = ['redTotalExperience', 'redTotalJungleMinionsKilled',
        'redTotalMinionsKilled','blueGoldPerMin','redGoldPerMin',
        'redCSPerMin','blueTotalJungleMinionsKilled','blueTotalMinionsKilled',
        'blueTotalExperience','gameId','blueCSPerMin']
data_modf = data.drop(cols, axis=1)
data_modf
# Out:
#       blueWins  blueWardsPlaced  ...  redGoldDiff  redExperienceDiff
# 0            0               28  ...         -643                  8
# 1            0               12  ...         2908               1173
# 2            0               15  ...         1172               1033
# 3            0               43  ...         1321                  7
# 4            0               75  ...         1004               -230
# ...        ...              ...  ...          ...                ...
# 9874         1               17  ...        -2519              -2469
# 9875         1               54  ...         -782               -888
# 9876         0               23  ...         2416               1877
# 9877         0               14  ...          839               1085
# 9878         1               18  ...         -927                 58
#
# [9879 rows x 29 columns]

# %%
firstbloodsBlue=data_modf['blueFirstBlood'].shape[0]

blue = 0
for i in range(firstbloodsBlue):
    if(data_modf['blueFirstBlood'][i]==1):
        blue=blue+1
print(blue)

firstbloodsRed=data_modf['redFirstBlood'].shape[0]

red = 0
for i in range(firstbloodsRed):
    if(data_modf['redFirstBlood'][i]==1):
        red=red+1
print(red)


X = [blue,red]
# Out:
# 4987
# 4892

# %%
labels = 'REDTEAM', 'BLUETEAM'


fig1, ax1 = plt.subplots(figsize=(20,10))
ax1.pie(X, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
